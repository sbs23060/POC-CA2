# %%
import pandas as pd       
import seaborn as sb

df_ireland=pd.read_csv("ireland_production_index.csv")

df_ireland.head(5)
# Out:
#                                     Unnamed: 0  \
# 0  Source: Central Statistics Office, Ireland.
# 1                                       2000Q1
# 2                                       2000Q2
# 3                                       2000Q3
# 4                                       2000Q4
#
#    Value of Production Index in Building and Construction  \
# 0                                                NaN
# 1                                            143.515
# 2                                            153.542
# 3                                            162.664
# 4                                            163.688
#
#    Volume of Production Index in Building and Construction  \
# 0                                                NaN
# 1                                            206.820
# 2                                            216.692
# 3                                            228.747
# 4                                            221.786
#
# ...
